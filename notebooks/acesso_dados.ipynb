# %%
# %python
dbutils.fs.mkdirs("/mnt/dados/inbound")
dbutils.fs.mkdirs("/mnt/dados/bronze")
dbutils.fs.mkdirs("/mnt/dados/silver")

# %%
# %python
dbutils.fs.ls("/mnt")

# %%
# %scala
val configs = Map(
  "fs.azure.account.auth.type" -> "OAuth",
  "fs.azure.account.oauth.provider.type" -> "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
  "fs.azure.account.oauth2.client.id" -> "496f876a-876b-473a-aae4-9d9cbd6b0910",
  "fs.azure.account.oauth2.client.secret" -> "MpW8Q~2jGKAqdfiQN1WfBL-1SPfTeFCeR6Xpjbpc",
  "fs.azure.account.oauth2.client.endpoint" -> "https://login.microsoftonline.com/a175a854-e046-464d-a5fc-24715744bd98/oauth2/token")
// Optionally, you can add <directory-name> to the source URI of your mount point.

dbutils.fs.mount(
  source = "abfss://imoveis@datalakealurafabiano.dfs.core.windows.net/",
  mountPoint = "/mnt/dados",
  extraConfigs = configs)

# %%
# %python
display(dbutils.fs.ls("/mnt/dados"))
