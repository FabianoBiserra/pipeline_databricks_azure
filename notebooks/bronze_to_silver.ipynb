// %% [markdown]
// ### Conferindo se os dados foram montados e se temos acess a pasta bronze

// %%
%python
display(dbutils.fs.ls("/mnt/dados/bronze"))

// %% [markdown]
// ## Lendo os dados na camada Bronze

// %%
val path = "dbfs:/mnt/dados/bronze/dataset_imoveis/"

val df = spark.read.format("delta").load(path)

// %%
display(df)

// %% [markdown]
// ### Transformando os campos Json em Colunas

// %%
display(df.select("anuncio.*"))

// %%
display(df.select("anuncio.*", "anuncio.endereco.*"))

// %%
val dados_detalhados = df.select("anuncio.*", "anuncio.endereco.*")

// %%
val df_silver = dados_detalhados.drop("caracteristicas", "endereco")

// %%
display(df_silver)

// %% [markdown]
// ### Salvando na camada Silver

// %%
val path = "/mnt/dados/silver/dataset_imoveis/"

df_silver.write.format("delta").mode("overwrite").save(path)

// %%
%python
display(dbutils.fs.ls("/mnt/dados/silver"))
